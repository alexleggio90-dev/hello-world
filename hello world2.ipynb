# %% [markdown]
# <a href="https://colab.research.google.com/github/alexleggio90-dev/hello-world/blob/Progetto-downloader/hello%20world2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U yt-dlp
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.8/183.8 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 54.8 MB/s eta 0:00:00
# ...

# %%
# !python main.py
# Out:
# --- MOTORE BACKEND AUDIO AVVIATO ---
#
# Inserisci link YouTube (o 'q' per uscire): https://www.youtube.com/watch?v=8QmwRuSd7xQ
# Cartella di salvataggio (es. 'download'): content
# Nome del file (senza estensione): prova1
# 📥 Inizio download...
# Extracting cookies from chrome
# ERROR: could not find chrome cookies database in "/root/.config/google-chrome"
# ❌ Operazione fallita. Controlla 'backend.log' per i dettagli.
#
# Inserisci link YouTube (o 'q' per uscire): https://www.youtube.com/watch?v=8QmwRuSd7xQ
# Cartella di salvataggio (es. 'download'):
# Nome del file (senza estensione):
# 📥 Inizio download...
# Extracting cookies from chrome
# ERROR: could not find chrome cookies database in "/root/.config/google-chrome"
# ❌ Operazione fallita. Controlla 'backend.log' per i dettagli.
#
# Inserisci link YouTube (o 'q' per uscire):
